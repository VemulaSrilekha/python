# %%
import nltk

# %%
filename='C:\\Users\\DELL\\Downloads\\Text Cleaning Manually and with NLTK-Part-1.ipynb'

# %%
file=open(filename,'rt')

# %%
dir(nltk)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'AbstractLazySequence',
#  'AffixTagger',
#  'AlignedSent',
#  'Alignment',
#  'AnnotationTask',
#  'ApplicationExpression',
#  'Assignment',
#  'BigramAssocMeasures',
#  'BigramCollocationFinder',
#  'BigramTagger',
#  'BinaryMaxentFeatureEncoding',
#  'BlanklineTokenizer',
#  'BllipParser',
#  'BottomUpChartParser',
#  'BottomUpLeftCornerChartParser',
#  'BottomUpProbabilisticChartParser',
#  'Boxer',
#  'BrillTagger',
#  'BrillTaggerTrainer',
#  'CFG',
#  'CRFTagger',
#  'CfgReadingCommand',
#  'ChartParser',
#  'ChunkParserI',
#  'ChunkScore',
#  'Cistem',
#  'ClassifierBasedPOSTagger',
#  'ClassifierBasedTagger',
#  'ClassifierI',
#  'ConcordanceIndex',
#  'ConditionalExponentialClassifier',
#  'ConditionalFreqDist',
#  'ConditionalProbDist',
#  'ConditionalProbDistI',
#  'ConfusionMatrix',
#  'ContextIndex',
#  'ContextTagger',
#  'ContingencyMeasures',
#  'CoreNLPDependencyParser',
#  'CoreNLPParser',
#  'Counter',
#  'CrossValidationProbDist',
# ...

# %%
file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\DELL\\Downloads\\Text Cleaning Manually and with NLTK-Part-1.ipynb' mode='rt' encoding='cp1252'>

# %%
text=file.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 text=file.read()
#
# File ~\anaconda3\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 450311: character maps to <undefined>

# %%
text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 text
#
# NameError: name 'text' is not defined

# %%
filename='C:\\Users\\DELL\\Downloads\\Text Cleaning Manually and with NLTK-Part-1.ipynb'
file=open(filename,'rt')
text=file.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[28], line 3
#       1 filename='C:\\Users\\DELL\\Downloads\\Text Cleaning Manually and with NLTK-Part-1.ipynb'
#       2 file=open(filename,'rt')
# ----> 3 text=file.read()
#
# File ~\anaconda3\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 450311: character maps to <undefined>

# %%
print(text)

# %%
len(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(words)
#
# NameError: name 'words' is not defined

# %% [markdown]
# $punctuations$

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
len(string.punctuation)
# Out:
# 32

# %% [markdown]
# $re$

# %%
import re

# %%
re_punct=re.compile('[%s]'%re.escape(string.punctuation))

# %%
import re  # regex
text1="hai kows$$$hik what's u&p"
words=text1.split()
print(words)
re_punct=re.compile('[%s]'%re.escape(string.punctuation))
w=[re_punct.sub('',w) for w in words]
print(w)
# Out:
# ['hai', 'kows$$$hik', "what's", 'u&p']
# ['hai', 'kowshik', 'whats', 'up']

# %%
def text_cleaning(text1):
    words=text1.split()
    re_punct=re.compile('[%s]'%re.escape(string.punctuation))
    w=[re_punct.sub('',w) for w in words]
    return (w)

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
# load data
filename='C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\Datasets\\metamorphosis clean.txt'
file=open(filename,'rt')
text=file.read()
# split into words
tokens=word_tokenize(text)
print(tokens[:4])
# will remove all tokens that are not alphabetic
words= [word for word in tokens if word.isalpha()]
words[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 4
#       2 # load data
#       3 filename='C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Ekeeda\\Datasets\\metamorphosis clean.txt'
# ----> 4 file=open(filename,'rt')
#       5 text=file.read()
#       6 # split into words
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# ...
